# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_excel("university.xlsx")

# %%
data.shape
# Out:
# (3400, 56)

# %%
data.head()
# Out:
#    STUDENT IDENTIFIER  STDNT_AGE STDNT_GENDER STDNT_BACKGROUND IN_STATE_FLAG  \
# 0             7808615         18            F            BGD 1             Y
# 1             7830063         19            F            BGD 1             N
# 2             7847538         18            M            BGD 1             Y
# 3             8006429         18            M            BGD 1             Y
# 4             7962680         18            F            BGD 1             Y
#
#   INTERNATIONAL_STS  STDNT_MAJOR STDNT_MINOR  STDNT_TEST_ENTRANCE1  \
# 0                 N   Undeclared           N                   NaN
# 1                 N   Undeclared           N                  26.0
# 2                 N  Mathematics           N                   NaN
# 3                 N   Undeclared           N                   NaN
# 4                 N          Art           N                   NaN
#
#    STDNT_TEST_ENTRANCE2  ...  DEGREE_GROUP_CD  DEGREE_GROUP_DESC  \
# ...

# %%
data.isnull().sum()
# Out:
# STUDENT IDENTIFIER             0
# STDNT_AGE                      0
# STDNT_GENDER                   0
# STDNT_BACKGROUND               0
# IN_STATE_FLAG                  0
# INTERNATIONAL_STS              0
# STDNT_MAJOR                    0
# STDNT_MINOR                    0
# STDNT_TEST_ENTRANCE1        2294
# STDNT_TEST_ENTRANCE2         908
# STDNT_TEST_ENTRANCE_COMB     518
# FIRST_TERM                     0
# CORE_COURSE_NAME_1_F           0
# CORE_COURSE_GRADE_1_F          0
# CORE_COURSE_NAME_2_F          99
# CORE_COURSE_GRADE_2_F         99
# CORE_COURSE_NAME_3_F         565
# CORE_COURSE_GRADE_3_F        565
# CORE_COURSE_NAME_4_F        1597
# CORE_COURSE_GRADE_4_F       1597
# CORE_COURSE_NAME_5_F        2755
# CORE_COURSE_GRADE_5_F       2755
# CORE_COURSE_NAME_6_F        3272
# CORE_COURSE_GRADE_6_F       3272
# SECOND_TERM                    0
# CORE_COURSE_NAME_1_S         157
# CORE_COURSE_GRADE_1_S        232
# CORE_COURSE_NAME_2_S         439
# ...

# %%
data.describe()
# Out:
#        STUDENT IDENTIFIER    STDNT_AGE  STDNT_TEST_ENTRANCE1  \
# count        3.400000e+03  3400.000000           1106.000000
# mean         7.897155e+06    17.994118             20.660036
# std          8.083421e+04     0.552052              3.234734
# min          7.755837e+06    16.000000              8.000000
# 25%          7.827039e+06    18.000000             18.000000
# 50%          7.899052e+06    18.000000             20.000000
# 75%          7.964008e+06    18.000000             22.000000
# max          8.037098e+06    26.000000             32.000000
#
#        STDNT_TEST_ENTRANCE2  STDNT_TEST_ENTRANCE_COMB     FIRST_TERM  \
# count           2492.000000               2882.000000    3400.000000
# mean             965.092295                997.758501  200777.000000
# std              209.088633                156.268221     170.001298
# min              350.000000                530.000000  200508.000000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3400 entries, 0 to 3399
# Data columns (total 56 columns):
# STUDENT IDENTIFIER          3400 non-null int64
# STDNT_AGE                   3400 non-null int64
# STDNT_GENDER                3400 non-null object
# STDNT_BACKGROUND            3400 non-null object
# IN_STATE_FLAG               3400 non-null object
# INTERNATIONAL_STS           3400 non-null object
# STDNT_MAJOR                 3400 non-null object
# STDNT_MINOR                 3400 non-null object
# STDNT_TEST_ENTRANCE1        1106 non-null float64
# STDNT_TEST_ENTRANCE2        2492 non-null float64
# STDNT_TEST_ENTRANCE_COMB    2882 non-null float64
# FIRST_TERM                  3400 non-null int64
# CORE_COURSE_NAME_1_F        3400 non-null object
# CORE_COURSE_GRADE_1_F       3400 non-null object
# CORE_COURSE_NAME_2_F        3301 non-null object
# CORE_COURSE_GRADE_2_F       3301 non-null object
# CORE_COURSE_NAME_3_F        2835 non-null object
# ...

# %%
data['total']=data['GROSS_FIN_NEED']+data['COST_OF_ATTEND']

# %%
data.head(2)
# Out:
#    STUDENT IDENTIFIER  STDNT_AGE STDNT_GENDER STDNT_BACKGROUND IN_STATE_FLAG  \
# 0             7808615         18            F            BGD 1             Y
# 1             7830063         19            F            BGD 1             N
#
#   INTERNATIONAL_STS STDNT_MAJOR STDNT_MINOR  STDNT_TEST_ENTRANCE1  \
# 0                 N  Undeclared           N                   NaN
# 1                 N  Undeclared           N                  26.0
#
#    STDNT_TEST_ENTRANCE2  ...  DEGREE_GROUP_DESC  FIRST_TERM_ATTEMPT_HRS  \
# 0                1150.0  ...          Bachelors                      16
# 1                   NaN  ...          Bachelors                      18
#
#   FIRST_TERM_EARNED_HRS SECOND_TERM_ATTEMPT_HRS SECOND_TERM_EARNED_HRS  \
# 0                    16                    14.0                   14.0
# 1                    18                    18.0                   18.0
#
#   GROSS_FIN_NEED COST_OF_ATTEND EST_FAM_CONTRIBUTION UNMET_NEED    total
# ...

# %%
data['feesleft']=data['COST_OF_ATTEND']-data['EST_FAM_CONTRIBUTION']

# %%
data.head(2)
# Out:
#    STUDENT IDENTIFIER  STDNT_AGE STDNT_GENDER STDNT_BACKGROUND IN_STATE_FLAG  \
# 0             7808615         18            F            BGD 1             Y
# 1             7830063         19            F            BGD 1             N
#
#   INTERNATIONAL_STS STDNT_MAJOR STDNT_MINOR  STDNT_TEST_ENTRANCE1  \
# 0                 N  Undeclared           N                   NaN
# 1                 N  Undeclared           N                  26.0
#
#    STDNT_TEST_ENTRANCE2  ...  FIRST_TERM_ATTEMPT_HRS  FIRST_TERM_EARNED_HRS  \
# 0                1150.0  ...                      16                     16
# 1                   NaN  ...                      18                     18
#
#   SECOND_TERM_ATTEMPT_HRS SECOND_TERM_EARNED_HRS GROSS_FIN_NEED  \
# 0                    14.0                   14.0              0
# 1                    18.0                   18.0         570000
#
#   COST_OF_ATTEND EST_FAM_CONTRIBUTION UNMET_NEED    total feesleft
# ...

# %%
data['monshortage']=data['feesleft']+data['UNMET_NEED']

# %%
data.head(5)
# Out:
#    STUDENT IDENTIFIER  STDNT_AGE STDNT_GENDER STDNT_BACKGROUND IN_STATE_FLAG  \
# 0             7808615         18            F            BGD 1             Y
# 1             7830063         19            F            BGD 1             N
# 2             7847538         18            M            BGD 1             Y
# 3             8006429         18            M            BGD 1             Y
# 4             7962680         18            F            BGD 1             Y
#
#   INTERNATIONAL_STS  STDNT_MAJOR STDNT_MINOR  STDNT_TEST_ENTRANCE1  \
# 0                 N   Undeclared           N                   NaN
# 1                 N   Undeclared           N                  26.0
# 2                 N  Mathematics           N                   NaN
# 3                 N   Undeclared           N                   NaN
# 4                 N          Art           N                   NaN
#
#    STDNT_TEST_ENTRANCE2  ...  FIRST_TERM_EARNED_HRS  SECOND_TERM_ATTEMPT_HRS  \
# ...

# %%
data.STDNT_MAJOR.value_counts().nlargest(40).plot(kind='bar', figsize=(10,5))
plt.title("Number of students per department")
plt.ylabel('Departments')
plt.xlabel('Count')
# Out:
# Text(0.5, 0, 'Count')

# %%
data.STDNT_MAJOR.value_counts().plot(kind='bar', figsize=(10,5))
plt.title("Number of students per department")
plt.ylabel('Departments')
plt.xlabel('Count')
# Out:
# Text(0.5, 0, 'Count')

# %%
data.STDNT_GENDER.value_counts().plot(kind='bar',figsize=(15,5))
plt.title("Number of students per gender")
plt.ylabel("count")
plt.xlabel("Gender")
# Out:
# Text(0.5, 0, 'Gender')

# %%
data.groupby('STDNT_GENDER').RETURNED_2ND_YR.mean().reset_index().plot(kind='bar',figsize=(15,5))
plt.title("Number of students per gender")
plt.ylabel("count")
plt.xlabel("Gender")
# Out:
# Text(0.5, 0, 'Gender')

# %%
data.boxplot(column=['monshortage'])

# %%
data.hist(column=['monshortage'])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001DFDD0331D0>]],
#       dtype=object)

# %%
data.boxplot(column=['FIRST_TERM_ATTEMPT_HRS','FIRST_TERM_EARNED_HRS','SECOND_TERM_EARNED_HRS','SECOND_TERM_EARNED_HRS'])

# %%
data.hist(column=['FIRST_TERM_ATTEMPT_HRS','FIRST_TERM_EARNED_HRS','SECOND_TERM_EARNED_HRS','SECOND_TERM_EARNED_HRS'])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001DFDCC60940>,
# ...
#       dtype=object)

# %%
data.hist(column=['HIGH_SCHL_GPA'])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001DFDCE610B8>]],
#       dtype=object)

# %%
data.boxplot(column=['HIGH_SCHL_GPA'])

# %%
data.boxplot(column=['DISTANCE_FROM_HOME'])

# %%
data.hist(column=['DISTANCE_FROM_HOME'])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001DFDEB5F4A8>]],
#       dtype=object)

# %%
f,ax = plt.subplots(figsize=(18, 18))
sns.heatmap(data.corr(), annot=True, linewidths=.5, fmt= '.1f',ax=ax)

# %%
data=data.drop(['STUDENT IDENTIFIER','STDNT_MAJOR','STDNT_MINOR','STDNT_TEST_ENTRANCE1','STDNT_TEST_ENTRANCE2','STDNT_TEST_ENTRANCE_COMB','FIRST_TERM','CORE_COURSE_NAME_1_F','CORE_COURSE_GRADE_1_F','CORE_COURSE_NAME_2_F','CORE_COURSE_GRADE_2_F','CORE_COURSE_NAME_3_F','CORE_COURSE_GRADE_3_F','CORE_COURSE_NAME_4_F','CORE_COURSE_GRADE_4_F','CORE_COURSE_NAME_5_F','CORE_COURSE_GRADE_5_F','CORE_COURSE_NAME_6_F','CORE_COURSE_GRADE_6_F'],axis=1)

# %%
data=data.drop(['SECOND_TERM','CORE_COURSE_NAME_1_S','CORE_COURSE_GRADE_1_S','CORE_COURSE_NAME_2_S','CORE_COURSE_GRADE_2_S','CORE_COURSE_NAME_3_S','CORE_COURSE_GRADE_3_S','CORE_COURSE_NAME_4_S','CORE_COURSE_GRADE_4_S','CORE_COURSE_NAME_5_S','CORE_COURSE_GRADE_5_S','CORE_COURSE_NAME_6_S','CORE_COURSE_GRADE_6_S','HIGH_SCHL_NAME','FATHER_HI_EDU_DESC','MOTHER_HI_EDU_DESC','GROSS_FIN_NEED','COST_OF_ATTEND','EST_FAM_CONTRIBUTION','UNMET_NEED'],axis=1)

# %%
data.shape
# Out:
# (3400, 20)

# %%
data=pd.get_dummies(data)

# %%
data=data.fillna(0)

# %%
X=data.drop(['RETURNED_2ND_YR'],axis=1)

# %%
X.shape
# Out:
# (3400, 34)

# %%
Y=data['RETURNED_2ND_YR']

# %%
import sklearn.model_selection as model_selection

X_train,X_test,Y_train,Y_test=model_selection.train_test_split(X,Y,test_size=0.3,random_state=200)

# %%
np.all(np.isfinite(data))
# Out:
# True

# %%
data = data.reset_index()

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
for i in range(30,600,10):
    reg=RandomForestClassifier(n_estimators=i,max_depth=5,max_features='sqrt',oob_score=True,random_state=200)
    reg.fit(X_train,Y_train)
    oob=reg.oob_score_
    print('For n_estimators = '+str(i))
    print('OOB score is '+str(oob))
    print('************************')
# Out:
# For n_estimators = 30
# OOB score is 0.8336134453781513
# ************************
# For n_estimators = 40
# OOB score is 0.8352941176470589
# ************************
# For n_estimators = 50
# OOB score is 0.8357142857142857
# ************************
# For n_estimators = 60
# OOB score is 0.8365546218487395
# ************************
# For n_estimators = 70
# OOB score is 0.8365546218487395
# ************************
# For n_estimators = 80
# OOB score is 0.8361344537815126
# ************************
# For n_estimators = 90
# OOB score is 0.8365546218487395
# ************************
# For n_estimators = 100
# OOB score is 0.8361344537815126
# ************************
# For n_estimators = 110
# OOB score is 0.8361344537815126
# ************************
# For n_estimators = 120
# OOB score is 0.8373949579831933
# ************************
# For n_estimators = 130
# OOB score is 0.8369747899159664
# ************************
# For n_estimators = 140
# OOB score is 0.8357142857142857
# ...

# %%
from sklearn import metrics
metrics.mean_squared_error(Y_test,classification.predict(X_test))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-61-54c58cf0778c> in <module>
#       1 from sklearn import metrics
# ----> 2 metrics.mean_squared_error(Y_test,classification.predict(X_test))
#
# NameError: name 'classification' is not defined

# %%
claasifier=RandomForestClassifier(n_estimators=350,max_depth=5,max_features='sqrt',oob_score=True)
claasifier.fit(X_train,Y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=5, max_features='sqrt', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=350,
#                        n_jobs=None, oob_score=True, random_state=None,
#                        verbose=0, warm_start=False)

# %%
claasifier.score(X_test,Y_test)
# Out:
# 0.8264705882352941

# %%
claasifier.oob_score_
# Out:
# 0.8361344537815126

# %%
claasifier.feature_importances_
# Out:
# array([1.17575315e-02, 2.34479597e-02, 4.26272274e-02, 9.47118647e-03,
#        8.72527257e-03, 2.03880574e-02, 5.37945908e-02, 3.33547498e-01,
#        3.57540766e-01, 2.17540807e-02, 2.04665816e-02, 3.05539133e-02,
#        6.57490542e-03, 6.26986003e-03, 5.17232716e-03, 7.91685131e-04,
#        7.35423359e-03, 2.87023226e-03, 4.24088476e-03, 1.38253754e-03,
#        2.30863587e-03, 5.27359021e-04, 4.26235158e-03, 3.44125732e-03,
#        3.54869789e-03, 2.28355797e-03, 6.32823600e-03, 5.16067718e-03,
#        2.21177163e-04, 6.00975534e-04, 6.91035798e-04, 2.49214570e-04,
#        7.13200077e-04, 9.32292393e-04])

# %%
imp_feat=pd.Series(claasifier.feature_importances_,index=X.columns.tolist())

# %%
imp_feat.sort_values(ascending=False)
# Out:
# SECOND_TERM_EARNED_HRS                0.357541
# SECOND_TERM_ATTEMPT_HRS               0.333547
# FIRST_TERM_EARNED_HRS                 0.053795
# HIGH_SCHL_GPA                         0.042627
# monshortage                           0.030554
# DISTANCE_FROM_HOME                    0.023448
# total                                 0.021754
# feesleft                              0.020467
# FIRST_TERM_ATTEMPT_HRS                0.020388
# STDNT_AGE                             0.011758
# FATHER_HI_EDU_CD                      0.009471
# MOTHER_HI_EDU_CD                      0.008725
# STDNT_BACKGROUND_BGD 3                0.007354
# STDNT_GENDER_F                        0.006575
# HOUSING_STS_Off Campus                0.006328
# STDNT_GENDER_M                        0.006270
# STDNT_BACKGROUND_BGD 1                0.005172
# HOUSING_STS_On Campus                 0.005161
# IN_STATE_FLAG_N                       0.004262
# STDNT_BACKGROUND_BGD 5                0.004241
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
pred=claasifier.predict(X_test)
pred
# Out:
# array([1, 1, 1, ..., 1, 0, 1], dtype=int64)

# %%
Errors=Y_test-pred

# %%
Errors.head(5)
# Out:
# 2200    0
# 228     0
# 2276    0
# 131     0
# 2694    0
# Name: RETURNED_2ND_YR, dtype: int64

# %%
plt.scatter(Y_test, Errors, alpha=0.4)

# %%
from sklearn import metrics

# %%
print("Accuracy:",metrics.accuracy_score(Y_test,pred))
# Out:
# Accuracy: 0.8264705882352941
